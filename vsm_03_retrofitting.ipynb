# %% [markdown]
# # Vector-space models: retrofitting

# %%
__author__ = "Christopher Potts"
__version__ = "CS224u, Stanford, Spring 2020"

# %% [markdown]
# ## Contents
#
# 1. [Overview](#Overview)
# 1. [Set-up](#Set-up)
# 1. [The retrofitting model](#The-retrofitting-model)
# 1. [Examples](#Examples)
#   1. [Only node 0 has outgoing edges](#Only-node-0-has-outgoing-edges)
#   1. [All nodes connected to all others](#All-nodes-connected-to-all-others)
#   1. [As before, but now 2 has no outgoing edges](#As-before,-but-now-2-has-no-outgoing-edges)
#   1. [All nodes connected to all others, but $\alpha = 0$](#All-nodes-connected-to-all-others,-but-$\alpha-=-0$)
# 1. [WordNet](#WordNet)
#   1. [Background on WordNet](#Background-on-WordNet)
#   1. [WordNet and VSMs](#WordNet-and-VSMs)
#   1. [Reproducing the WordNet synonym graph experiment](#Reproducing-the-WordNet-synonym-graph-experiment)
# 1. [Other retrofitting models and ideas](#Other-retrofitting-models-and-ideas)

# %% [markdown]
# ## Overview
#
# * Thus far, all of the information in our word vectors has come solely from co-occurrences patterns in text. This information is often very easy to obtain – though one does need a __lot__ of text – and it is striking how rich the resulting representations can be.
#
# * Nonetheless, it seems clear that there is important information that we will miss this way – relationships that just aren't encoded at all in co-occurrences or that get distorted by such patterns.
#
# * For example, it is probably straightforward to learn representations that will support the inference that all puppies are dogs (_puppy_ entails _dog_), but it might be difficult to learn that _dog_ entails _mammal_ because of the unusual way that very broad taxonomic terms like _mammal_ are used in text.
#
# * The question then arises: how can we bring structured information – labels – into our representations? If we can do that, then we might get the best of both worlds: the ease of using co-occurrence data and the refinement that comes from using labeled data.
#
# * In this notebook, we look at one powerful method for doing this: the __retrofitting__ model of [Faruqui et al. 2016](http://www.aclweb.org/anthology/N15-1184). In this model, one learns (or just downloads) distributed representations for nodes in a knowledge graph and then updates those representations to bring connected nodes closer to each other.
#
# * This is an incredibly fertile idea; the final section of the notebook reviews some recent extensions, and new ones are likely appearing all the time.

# %% [markdown]
# ## Set-up

# %%
# %matplotlib inline
from collections import defaultdict
from nltk.corpus import wordnet as wn
import numpy as np
import os
import pandas as pd
import retrofitting
from retrofitting import Retrofitter
import utils

# %%
data_home = 'data'

# %% [markdown]
# ## The retrofitting model
#
# For an __an existing VSM__ $\widehat{Q}$ of dimension $m \times n$, and a set of __edges__  $E$ (pairs of indices into rows in  $\widehat{Q}$), the retrofitting objective is to obtain a new VSM $Q$ (also dimension $m \times n$)  according to the following objective:
#
# $$\sum_{i=1}^{m} \left[
# \alpha_{i}\|q_{i} - \widehat{q}_{i}\|_{2}^{2}
# +
# \sum_{j : (i,j) \in E}\beta_{ij}\|q_{i} - q_{j}\|_{2}^{2}
# \right]$$
#
# The left term encodes a pressure to stay like the original vector. The right term encodes a pressure to be more like one's neighbors. In minimizing this objective, we should be able to strike a balance between old and new, VSM and graph.
#
# Definitions:
#
# 1. $\|u - v\|_{2}^{2}$ gives the __squared euclidean distance__ from $u$ to $v$.
#
# 1. $\alpha$ and $\beta$ are weights we set by hand, controlling the relative strength of the two pressures. In the paper, they use $\alpha=1$ and $\beta = \frac{1}{\{j : (i, j) \in E\}}$.

# %% [markdown]
# ## Examples
#
# To get a feel for what's happening, it's helpful to visualize the changes that occur in small, easily understood VSMs and graphs. The function `retrofitting.plot_retro_path` helps with this.

# %%
Q_hat = pd.DataFrame(
    [[0.0, 0.0],
     [0.0, 0.5],
     [0.5, 0.0]], 
    columns=['x', 'y'])

Q_hat
# Out:
#      x    y
# 0  0.0  0.0
# 1  0.0  0.5
# 2  0.5  0.0

# %% [markdown]
# ### Only node 0 has outgoing edges

# %%
edges_0 = {0: {1, 2}, 1: set(), 2: set()}

_ = retrofitting.plot_retro_path(Q_hat, edges_0)

# %% [markdown]
# ### All nodes connected to all others

# %%
edges_all = {0: {1, 2}, 1: {0, 2}, 2: {0, 1}}

_ = retrofitting.plot_retro_path(Q_hat, edges_all)

# %% [markdown]
# ### As before, but now 2 has no outgoing edges

# %%
edges_isolated = {0: {1, 2}, 1: {0, 2}, 2: set()}

_ = retrofitting.plot_retro_path(Q_hat, edges_isolated)

# %% [markdown]
# ### All nodes connected to all others, but $\alpha = 0$

# %%
_ = retrofitting.plot_retro_path(
    Q_hat, edges_all, 
    retrofitter=Retrofitter(alpha=lambda x: 0))

# %% [markdown]
# ## WordNet
#
# Faruqui et al. conduct experiments on three knowledge graphs: [WordNet](https://wordnet.princeton.edu), [FrameNet](https://framenet.icsi.berkeley.edu/fndrupal/), and the [Penn Paraphrase Database (PPDB)](http://paraphrase.org/). [The repository for their paper](https://github.com/mfaruqui/retrofitting) includes the graphs that they derived for their experiments.
#
# Here, we'll reproduce just one of the two WordNet experiments they report, in which the graph is formed based on synonymy.

# %% [markdown]
# ### Background on WordNet
#
# WordNet is an incredible, hand-built lexical resource capturing a wealth of information about English words and their inter-relationships. ([Here is a collection of WordNets in other languages.](http://globalwordnet.org)) For a detailed overview using NLTK, see [this tutorial](http://compprag.christopherpotts.net/wordnet.html).
#
# The core concepts:
#
# * A __lemma__ is something like our usual notion of __word__. Lemmas are highly sense-disambiguated. For instance, there are six lemmas that are consistent with the string `crane`: the bird, the machine, the poets, ...
#
# * A __synset__ is a collection of lemmas that are synonymous in the WordNet sense (which is WordNet-specific; words with intuitively different meanings might still be grouped together into synsets.).
#
# WordNet is a graph of relations between lemmas and between synsets, capturing things like hypernymy, antonymy, and many others. For the most part, the relations are defined between nouns; the graph is sparser for other areas of the lexicon.

# %%
lems = wn.lemmas('crane', pos=None)

for lem in lems:
    ss = lem.synset()
    print("="*70)
    print("Lemma name: {}".format(lem.name()))
    print("Lemma Synset: {}".format(ss))
    print("Synset definition: {}".format(ss.definition()))
# Out:
# ======================================================================
# Lemma name: Crane
# Lemma Synset: Synset('crane.n.01')
# Synset definition: United States writer (1871-1900)
# ======================================================================
# Lemma name: Crane
# Lemma Synset: Synset('crane.n.02')
# Synset definition: United States poet (1899-1932)
# ======================================================================
# Lemma name: Crane
# Lemma Synset: Synset('grus.n.01')
# Synset definition: a small constellation in the southern hemisphere near Phoenix
# ======================================================================
# Lemma name: crane
# Lemma Synset: Synset('crane.n.04')
# Synset definition: lifts and moves heavy objects; lifting tackle is suspended from a pivoted boom that rotates around a vertical axis
# ======================================================================
# Lemma name: crane
# Lemma Synset: Synset('crane.n.05')
# Synset definition: large long-necked wading bird of marshes and plains in many parts of the world
# ======================================================================
# Lemma name: crane
# Lemma Synset: Synset('crane.v.01')
# Synset definition: stretch (the neck) so as to see better

# %% [markdown]
# ### WordNet and VSMs
#
# A central challenge of working with WordNet is that one doesn't usually encounter lemmas or synsets in the wild. One probably gets just strings, or maybe strings with part-of-speech tags. Mapping these objects to lemmas is incredibly difficult.
#
# For our experiments with VSMs, we simply collapse together all the senses that a given string can have. This is expedient, of course. It might also be a good choice linguistically: senses are flexible and thus hard to individuate, and we might hope that our vectors can model multiple senses at the same time.
#
# (That said, there is excellent work on creating sense-vectors; see [Reisinger and Mooney 2010](http://www.aclweb.org/anthology/N10-1013); [Huang et al 2012](http://www.aclweb.org/anthology/P12-1092).)
#
# The following code uses the NLTK WordNet API to create the edge dictionary we need for using the `Retrofitter` class:

# %%
x = wn.all_synsets()

# %%
x_list = list(x)

# %%
ss = x_list[0]
print(ss)
print(ss.definition())
lem_names = {lem.name() for lem in ss.lemmas()}
print(lem_names)

ss = x_list[100]
print(ss)
print(ss.definition())
lem_names = {lem.name() for lem in ss.lemmas()}
print(lem_names)
# Out:
# Synset('able.a.01')
# (usually followed by `to') having the necessary means or skill or know-how or authority to do something
# {'able'}
# Synset('unaccommodating.a.01')
# not accommodating
# {'unobliging', 'unaccommodating'}

# %%
def get_wordnet_edges():
    edges = defaultdict(set)
    for ss in wn.all_synsets():
        lem_names = {lem.name() for lem in ss.lemmas()}
        for lem in lem_names:
            edges[lem] |= lem_names
    return edges

# %%
wn_edges = get_wordnet_edges()

# %%
wn_edges
# Out:
# defaultdict(set,
#             {'able': {'able', 'able-bodied', 'capable'},
#              'unable': {'ineffective', 'ineffectual', 'unable'},
#              'dorsal': {'abaxial', 'dorsal'},
#              'abaxial': {'abaxial', 'dorsal'},
#              'ventral': {'adaxial', 'ventral'},
#              'adaxial': {'adaxial', 'ventral'},
#              'acroscopic': {'acroscopic'},
#              'basiscopic': {'basiscopic'},
#              'abducent': {'abducens',
#               'abducens_nerve',
#               'abducent',
#               'abducent_nerve',
#               'abducting',
#               'nervus_abducens',
#               'sixth_cranial_nerve'},
#              'abducting': {'abducent', 'abducting'},
#              'adducting': {'adducent', 'adducting', 'adductive'},
#              'adductive': {'adducent', 'adducting', 'adductive'},
#              'adducent': {'adducent', 'adducting', 'adductive'},
#              'nascent': {'nascent'},
#              'emergent': {'emergent', 'emerging'},
#              'emerging': {'emergent', 'emerging', 'rising'},
#              'dissilient': {'dissilient'},
#              'parturient': {'parturient'},
#              'dying': {'anxious', 'death', 'demise', 'dying'},
#              'moribund': {'moribund', 'stagnant'},
#              'last': {'close',
#               "cobbler's_last",
#               'concluding',
#               'conclusion',
#               'death',
#               'end',
#               'endure',
#               'final',
#               'final_stage',
#               'finale',
#               'finally',
#               'finis',
#               'finish',
#               'go',
#               'hold_out',
#               'hold_up',
#               'in_conclusion',
#               'last',
#               'last-place',
#               'lastly',
#               'live',
#               'live_on',
#               'lowest',
#               'net',
#               "shoemaker's_last",
#               'stopping_point',
#               'survive',
#               'terminal',
#               'utmost'},
#              'abridged': {'abridged'},
#              'cut': {'abbreviate',
#               'abridge',
#               'baseball_swing',
#               'bring_down',
#               'burn',
#               'cold_shoulder',
#               'contract',
#               'curve',
#               'cut',
#               'cut_back',
#               'cut_down',
#               'cut_of_meat',
#               'cut_off',
#               'cutting',
#               'cutting_off',
#               'deletion',
#               'dilute',
#               'disregard',
#               'edit',
#               'edit_out',
#               'emasculated',
#               'excision',
#               'foreshorten',
#               'gash',
#               'geld',
#               'gelded',
#               'hack',
#               'ignore',
#               'issue',
#               'make_out',
#               'mown',
#               'prune',
#               'rationalise',
#               'rationalize',
#               'reduce',
#               'sheer',
#               'shorten',
#               'shortened',
#               'skip',
#               'slash',
#               'slashed',
#               'slew',
#               'slice',
#               'slue',
#               'snub',
#               'stinger',
#               'swerve',
#               'swing',
#               'switch_off',
#               'tailor',
#               'thin',
#               'thin_out',
#               'thinned',
#               'track',
#               'trend',
#               'trim',
#               'trim_back',
#               'trim_down',
#               'trimmed',
#               'turn_off',
#               'turn_out',
#               'undercut',
#               'veer',
#               'weakened',
#               'write_out'},
#              'shortened': {'abbreviated',
#               'cut',
#               'sawed-off',
#               'sawn-off',
#               'shortened',
#               'telescoped',
#               'truncated'},
#              'half-length': {'half-length'},
#              'potted': {'potted'},
#              'unabridged': {'unabridged', 'unabridged_dictionary'},
#              'full-length': {'full-length', 'uncut'},
#              'uncut': {'full-length', 'rough', 'uncut', 'unmown', 'untrimmed'},
#              'absolute': {'absolute',
#               'downright',
#               'infrangible',
#               'inviolable',
#               'out-and-out',
#               'rank',
#               'right-down',
#               'sheer'},
#              'direct': {'address',
#               'aim',
#               'calculate',
#               'channelise',
#               'channelize',
#               'conduct',
#               'direct',
#               'directly',
#               'engineer',
#               'guide',
#               'head',
#               'lead',
#               'lineal',
#               'maneuver',
#               'manoeuver',
#               'manoeuvre',
#               'mastermind',
#               'orchestrate',
#               'organise',
#               'organize',
#               'place',
#               'point',
#               'send',
#               'steer',
#               'straight',
#               'take',
#               'take_aim',
#               'target',
#               'train',
#               'unmediated',
#               'verbatim'},
#              'implicit': {'implicit', 'inexplicit', 'unquestioning'},
#              'unquestioning': {'implicit', 'unquestioning'},
#              'infinite': {'countless',
#               'infinite',
#               'innumerable',
#               'innumerous',
#               'multitudinous',
#               'myriad',
#               'non-finite',
#               'numberless',
#               'space',
#               'uncounted',
#               'unnumberable',
#               'unnumbered',
#               'unnumerable'},
#              'living': {'aliveness',
#               'animation',
#               'bread_and_butter',
#               'keep',
#               'life',
#               'livelihood',
#               'living',
#               'support',
#               'surviving',
#               'sustenance'},
#              'comparative': {'comparative', 'comparative_degree', 'relative'},
#              'relative': {'comparative',
#               'congenator',
#               'congener',
#               'congeneric',
#               'proportional',
#               'relation',
#               'relative'},
#              'relational': {'relational'},
#              'absorbent': {'absorbent', 'absorbent_material', 'absorptive'},
#              'absorptive': {'absorbent', 'absorptive'},
#              'sorbefacient': {'absorbefacient', 'sorbefacient'},
#              'absorbefacient': {'absorbefacient', 'sorbefacient'},
#              'assimilating': {'assimilating', 'assimilative', 'assimilatory'},
#              'assimilative': {'assimilating', 'assimilative', 'assimilatory'},
#              'assimilatory': {'assimilating', 'assimilative', 'assimilatory'},
#              'hygroscopic': {'hygroscopic'},
#              'receptive': {'centripetal', 'open', 'receptive', 'sensory'},
#              'shock-absorbent': {'shock-absorbent'},
#              'spongelike': {'spongelike', 'spongy', 'squashy', 'squishy'},
#              'spongy': {'spongelike', 'spongy', 'squashy', 'squishy'},
#              'thirsty': {'athirst', 'hungry', 'thirsty'},
#              'nonabsorbent': {'nonabsorbent', 'nonabsorptive'},
#              'nonabsorptive': {'nonabsorbent', 'nonabsorptive'},
#              'repellent': {'disgustful',
#               'disgusting',
#               'distasteful',
#               'foul',
#               'loathly',
#               'loathsome',
#               'rebarbative',
#               'repellant',
#               'repellent',
#               'repelling',
#               'resistant',
#               'revolting',
#               'skanky',
#               'wicked',
#               'yucky'},
#              'resistant': {'immune',
#               'insubordinate',
#               'repellent',
#               'resistant',
#               'resistive',
#               'tolerant'},
#              'adsorbent': {'adsorbent',
#               'adsorbent_material',
#               'adsorptive',
#               'surface-assimilative'},
#              'adsorptive': {'adsorbent', 'adsorptive', 'surface-assimilative'},
#              'surface-assimilative': {'adsorbent',
#               'adsorptive',
#               'surface-assimilative'},
#              'chemisorptive': {'chemisorptive', 'chemosorptive'},
#              'chemosorptive': {'chemisorptive', 'chemosorptive'},
#              'nonadsorptive': {'nonadsorbent', 'nonadsorptive'},
#              'nonadsorbent': {'nonadsorbent', 'nonadsorptive'},
#              'absorbable': {'absorbable'},
#              'adsorbable': {'adsorbable', 'adsorbate'},
#              'adsorbate': {'adsorbable', 'adsorbate'},
#              'abstemious': {'abstemious', 'light'},
#              'abstinent': {'abstainer',
#               'abstentious',
#               'abstinent',
#               'nondrinker'},
#              'abstentious': {'abstentious', 'abstinent'},
#              'austere': {'ascetic',
#               'ascetical',
#               'austere',
#               'severe',
#               'spartan',
#               'stark',
#               'stern'},
#              'spartan': {'ascetic',
#               'ascetical',
#               'austere',
#               'severe',
#               'spartan'},
#              'ascetical': {'ascetic', 'ascetical', 'austere', 'spartan'},
#              'ascetic': {'abstainer',
#               'ascetic',
#               'ascetical',
#               'austere',
#               'spartan'},
#              'gluttonous': {'gluttonous'},
#              'crapulous': {'crapulent', 'crapulous'},
#              'crapulent': {'crapulent', 'crapulous'},
#              'wolfish': {'edacious',
#               'esurient',
#               'rapacious',
#               'ravening',
#               'ravenous',
#               'voracious',
#               'wolfish',
#               'wolflike'},
#              'esurient': {'avid',
#               'devouring',
#               'edacious',
#               'esurient',
#               'famished',
#               'greedy',
#               'rapacious',
#               'ravening',
#               'ravenous',
#               'sharp-set',
#               'starved',
#               'voracious',
#               'wolfish'},
#              'voracious': {'edacious',
#               'esurient',
#               'rapacious',
#               'ravening',
#               'ravenous',
#               'voracious',
#               'wolfish'},
#              'edacious': {'edacious',
#               'esurient',
#               'rapacious',
#               'ravening',
#               'ravenous',
#               'voracious',
#               'wolfish'},
#              'rapacious': {'edacious',
#               'esurient',
#               'predatory',
#               'rapacious',
#               'raptorial',
#               'ravening',
#               'ravenous',
#               'voracious',
#               'vulturine',
#               'vulturous',
#               'wolfish'},
#              'ravenous': {'edacious',
#               'esurient',
#               'famished',
#               'rapacious',
#               'ravening',
#               'ravenous',
#               'sharp-set',
#               'starved',
#               'voracious',
#               'wolfish'},
#              'ravening': {'edacious',
#               'esurient',
#               'predatory',
#               'rapacious',
#               'raptorial',
#               'ravening',
#               'ravenous',
#               'voracious',
#               'vulturine',
#               'vulturous',
#               'wolfish'},
#              'greedy': {'avaricious',
#               'avid',
#               'covetous',
#               'devouring',
#               'esurient',
#               'grabby',
#               'grasping',
#               'greedy',
#               'prehensile'},
#              'piggish': {'hoggish', 'piggish', 'piggy', 'porcine', 'swinish'},
#              'swinish': {'boorish',
#               'hoggish',
#               'loutish',
#               'neandertal',
#               'neanderthal',
#               'oafish',
#               'piggish',
#               'piggy',
#               'porcine',
#               'swinish'},
#              'piggy': {'hoggish',
#               'piggish',
#               'piggy',
#               'piglet',
#               'porcine',
#               'shoat',
#               'shote',
#               'swinish'},
#              'porcine': {'gross',
#               'hoggish',
#               'piggish',
#               'piggy',
#               'porcine',
#               'swinish'},
#              'hoggish': {'hoggish', 'piggish', 'piggy', 'porcine', 'swinish'},
#              'overgreedy': {'overgreedy', 'too-greedy'},
#              'too-greedy': {'overgreedy', 'too-greedy'},
#              'abstract': {'abstract',
#               'abstraction',
#               'abstractionist',
#               'cabbage',
#               'filch',
#               'hook',
#               'lift',
#               'nobble',
#               'nonfigurative',
#               'nonobjective',
#               'outline',
#               'pilfer',
#               'pinch',
#               'precis',
#               'purloin',
#               'snarf',
#               'sneak',
#               'swipe',
#               'synopsis'},
#              'conceptional': {'conceptional', 'ideational', 'notional'},
#              'notional': {'conceptional',
#               'fanciful',
#               'ideational',
#               'imaginary',
#               'notional',
#               'speculative'},
#              'ideational': {'conceptional', 'ideational', 'notional'},
#              'conceptual': {'conceptual'},
#              'ideal': {'apotheosis',
#               'ideal',
#               'idealistic',
#               'nonesuch',
#               'nonpareil',
#               'nonsuch',
#               'paragon',
#               'saint'},
#              'ideological': {'ideologic', 'ideological'},
#              'ideologic': {'ideologic', 'ideological'},
#              'concrete': {'concrete'},
#              'objective': {'accusative',
#               'aim',
#               'documentary',
#               'nonsubjective',
#               'object',
#               'object_glass',
#               'object_lens',
#               'objective',
#               'objective_lens',
#               'target'},
#              'real': {'actual',
#               'existent',
#               'genuine',
#               'literal',
#               'material',
#               'rattling',
#               'real',
#               'real_number',
#               'really',
#               'substantial',
#               'tangible',
#               'veridical',
#               'very'},
#              'tangible': {'palpable', 'real', 'tangible', 'touchable'},
#              'abundant': {'abundant'},
#              'abounding': {'abounding', 'galore'},
#              'galore': {'abounding', 'galore'},
#              'plenteous': {'ample',
#               'copious',
#               'plenteous',
#               'plentiful',
#               'rich'},
#              'rich': {'ample',
#               'copious',
#               'deep',
#               'fat',
#               'fertile',
#               'full-bodied',
#               'plenteous',
#               'plentiful',
#               'productive',
#               'racy',
#               'rich',
#               'rich_people',
#               'robust'},
#              'plentiful': {'ample',
#               'bountiful',
#               'copious',
#               'plenteous',
#               'plentiful',
#               'rich'},
#              'copious': {'ample',
#               'copious',
#               'plenteous',
#               'plentiful',
#               'rich',
#               'voluminous'},
#              'ample': {'ample',
#               'copious',
#               'plenteous',
#               'plentiful',
#               'rich',
#               'sizable',
#               'sizeable'},
#              'voluminous': {'copious',
#               'tortuous',
#               'twisting',
#               'twisty',
#               'voluminous',
#               'winding'},
#              'easy': {'comfortable',
#               'easily',
#               'easy',
#               'easygoing',
#               'gentle',
#               'leisurely',
#               'light',
#               'loose',
#               'promiscuous',
#               'prosperous',
#               'slow',
#               'slowly',
#               'sluttish',
#               'soft',
#               'tardily',
#               'wanton',
#               'well-fixed',
#               'well-heeled',
#               'well-off',
#               'well-situated',
#               'well-to-do'},
#              'exuberant': {'ebullient',
#               'excessive',
#               'extravagant',
#               'exuberant',
#               'high-spirited',
#               'lush',
#               'luxuriant',
#               'overweening',
#               'profuse',
#               'riotous'},
#              'luxuriant': {'elaborate',
#               'epicurean',
#               'exuberant',
#               'lush',
#               'luxuriant',
#               'luxurious',
#               'profuse',
#               'riotous',
#               'sybaritic',
#               'voluptuary',
#               'voluptuous'},
#              'profuse': {'exuberant',
#               'lush',
#               'luxuriant',
#               'profuse',
#               'riotous'},
#              'riotous': {'debauched',
#               'degenerate',
#               'degraded',
#               'disruptive',
#               'dissipated',
#               'dissolute',
#               'exuberant',
#               'fast',
#               'libertine',
#               'lush',
#               'luxuriant',
#               'profligate',
#               'profuse',
#               'riotous',
#               'troubled',
#               'tumultuous',
#               'turbulent'},
#              'lush': {'alcoholic',
#               'alky',
#               'boozer',
#               'dipsomaniac',
#               'exuberant',
#               'lavish',
#               'lucullan',
#               'lush',
#               'luxuriant',
#               'plush',
#               'plushy',
#               'profuse',
#               'riotous',
#               'soaker',
#               'souse',
#               'succulent'},
#              'thick': {'blockheaded',
#               'boneheaded',
#               'buddy-buddy',
#               'chummy',
#               'compact',
#               'deep',
#               'dense',
#               'duncical',
#               'duncish',
#               'fatheaded',
#               'heavyset',
#               'loggerheaded',
#               'midst',
#               'slurred',
#               'stocky',
#               'thick',
#               'thick-skulled',
#               'thickheaded',
#               'thickly',
#               'thickset',
#               'wooden-headed'},
#              'long': {'farseeing',
#               'farsighted',
#               'foresighted',
#               'foresightful',
#               'hanker',
#               'long',
#               'longsighted',
#               'prospicient',
#               'recollective',
#               'retentive',
#               'tenacious',
#               'yearn'},
#              'rife': {'dominant',
#               'overabundant',
#               'plethoric',
#               'predominant',
#               'prevailing',
#               'prevalent',
#               'rife'},
#              'overabundant': {'overabundant', 'plethoric', 'rife'},
#              'plethoric': {'overabundant', 'plethoric', 'rife'},
#              'rampant': {'rampant', 'rearing'},
#              'rank': {'absolute',
#               'crying',
#               'downright',
#               'egregious',
#               'flagrant',
#               'glaring',
#               'grade',
#               'gross',
#               'membership',
#               'order',
#               'out-and-out',
#               'outrank',
#               'place',
#               'range',
#               'rank',
#               'rank_and_file',
#               'rate',
#               'right-down',
#               'sheer',
#               'social_rank',
#               'social_station',
#               'social_status'},
#              'superabundant': {'superabundant'},
#              'teeming': {'teeming'},
#              'torrential': {'torrential'},
#              'verdant': {'verdant'},
#              'scarce': {'barely', 'hardly', 'just', 'scarce', 'scarcely'},
#              'rare': {'rare', 'rarefied', 'rarified', 'uncommon'},
#              'tight': {'besotted',
#               'blind_drunk',
#               'blotto',
#               'close',
#               'closely',
#               'cockeyed',
#               'compressed',
#               'crocked',
#               'fast',
#               'fuddled',
#               'loaded',
#               'mean',
#               'mingy',
#               'miserly',
#               'nasty',
#               'pie-eyed',
#               'pissed',
#               'pixilated',
#               'plastered',
#               'rigorous',
#               'slopped',
#               'sloshed',
#               'smashed',
#               'soaked',
#               'soused',
#               'sozzled',
#               'squiffy',
#               'stiff',
#               'stringent',
#               'taut',
#               'tight',
#               'wet'},
#              'maltreated': {'abused',
#               'ill-treated',
#               'maltreated',
#               'mistreated'},
#              'mistreated': {'abused',
#               'ill-treated',
#               'maltreated',
#               'mistreated'},
#              'ill-treated': {'abused',
#               'ill-treated',
#               'maltreated',
#               'mistreated'},
#              'abused': {'abused', 'ill-treated', 'maltreated', 'mistreated'},
#              'battered': {'battered', 'beat-up', 'beaten-up'},
#              'unabused': {'unabused'},
#              'acceptable': {'acceptable', 'satisfactory'},
#              'bankable': {'bankable'},
#              'unimpeachable': {'blameless',
#               'inculpable',
#               'irreproachable',
#               'unexceptionable',
#               'unimpeachable'},
#              'unexceptionable': {'unexceptionable', 'unimpeachable'},
#              'unobjectionable': {'clean', 'innocuous', 'unobjectionable'},
#              'unacceptable': {'impossible',
#               'insufferable',
#               'unacceptable',
#               'unaccepted',
#               'unsufferable'},
#              'objectionable': {'exceptionable', 'objectionable', 'obnoxious'},
#              'exceptionable': {'exceptionable', 'objectionable'},
#              'accessible': {'accessible', 'approachable'},
#              'approachable': {'accessible', 'approachable', 'reachable'},
#              'reachable': {'approachable', 'reachable'},
#              'get-at-able': {'come-at-able', 'get-at-able', 'getatable'},
#              'come-at-able': {'attainable',
#               'come-at-able',
#               'get-at-able',
#               'getatable'},
#              'getatable': {'come-at-able', 'get-at-able', 'getatable'},
#              'ready_to_hand': {'handy', 'ready_to_hand'},
#              'handy': {'handy', 'ready_to_hand'},
#              'inaccessible': {'inaccessible',
#               'unaccessible',
#               'unobtainable',
#               'unprocurable',
#               'untouchable'},
#              'unaccessible': {'inaccessible', 'unaccessible'},
#              'remote': {'distant',
#               'outback',
#               'outside',
#               'remote',
#               'remote_control',
#               'removed'},
#              'outback': {'outback', 'remote'},
#              'trackless': {'pathless',
#               'roadless',
#               'trackless',
#               'untracked',
#               'untrod',
#               'untrodden'},
#              'roadless': {'pathless',
#               'roadless',
#               'trackless',
#               'untracked',
#               'untrod',
#               'untrodden'},
#              'untrod': {'pathless',
#               'roadless',
#               'trackless',
#               'untracked',
#               'untrod',
#               'untrodden'},
#              'pathless': {'pathless',
#               'roadless',
#               'trackless',
#               'untracked',
#               'untrod',
#               'untrodden'},
#              'untracked': {'pathless',
#               'roadless',
#               'trackless',
#               'untracked',
#               'untrod',
#               'untrodden'},
#              'untrodden': {'pathless',
#               'roadless',
#               'trackless',
#               'untracked',
#               'untrod',
#               'untrodden'},
#              'unapproachable': {'out_of_reach',
#               'unapproachable',
#               'unreachable',
#               'unreached'},
#              'out_of_reach': {'out_of_reach',
#               'unapproachable',
#               'unreachable',
#               'unreached'},
#              'unreached': {'out_of_reach',
#               'unapproachable',
#               'unreachable',
#               'unreached'},
#              'unreachable': {'out_of_reach',
#               'unapproachable',
#               'unreachable',
#               'unreached'},
#              'un-get-at-able': {'un-come-at-able',
#               'un-get-at-able',
#               'ungetatable'},
#              'un-come-at-able': {'un-come-at-able',
#               'un-get-at-able',
#               'ungetatable'},
#              'ungetatable': {'un-come-at-able',
#               'un-get-at-able',
#               'ungetatable'},
#              'accommodating': {'accommodating', 'accommodative'},
#              'accommodative': {'accommodating',
#               'accommodative',
#               'cooperative',
#               'reconciling'},
#              'complaisant': {'complaisant', 'obliging'},
#              'obliging': {'complaisant', 'obliging'},
#              'unobliging': {'unaccommodating', 'unobliging'},
#              'unaccommodating': {'unaccommodating', 'unobliging'},
#              'uncooperative': {'disobliging', 'uncooperative'},
#              'disobliging': {'disobliging', 'uncooperative'},
#              'accurate': {'accurate', 'exact', 'precise'},
#              'close': {'airless',
#               'cheeseparing',
#               'close',
#               'close-fitting',
#               'close_down',
#               'close_up',
#               'closelipped',
#               'closely',
#               'closemouthed',
#               'closing',
#               'closing_curtain',
#               'come_together',
#               'conclude',
#               'conclusion',
#               'confining',
#               'end',
#               'ending',
#               'faithful',
#               'fill_up',
#               'finale',
#               'finis',
#               'finish',
#               'fold',
#               'last',
#               'near',
#               'nigh',
#               'penny-pinching',
#               'secretive',
#               'shut',
#               'shut_down',
#               'skinny',
#               'snug',
#               'stopping_point',
#               'stuffy',
#               'tight',
#               'tightlipped',
#               'unaired'},
#              'faithful': {'close', 'congregation', 'faithful', 'fold'},
#              'dead-on': {'dead-on'},
#              'high-fidelity': {'hi-fi', 'high-fidelity'},
#              'hi-fi': {'hi-fi',
#               'high-fidelity',
#               'high_fidelity',
#               'high_fidelity_sound_system'},
#              'surgical': {'operative', 'surgical'},
#              'straight': {'consecutive',
#               'direct',
#               'directly',
#               'flat',
#               'full-strength',
#               'heterosexual',
#               'heterosexual_person',
#               'neat',
#               'square',
#               'straight',
#               'straight_person',
#               'straightaway',
#               'straightforward',
#               'true',
#               'unbent',
#               'unbowed',
#               'uncoiled'},
#              'true': {'admittedly',
#               'avowedly',
#               'confessedly',
#               'dead_on_target',
#               'dependable',
#               'genuine',
#               'honest',
#               'lawful',
#               'on-key',
#               'reliable',
#               'rightful',
#               'straight',
#               'true',
#               'true_up',
#               'truthful',
#               'unfeigned'},
#              'dead_on_target': {'dead_on_target', 'true'},
#              'veracious': {'right', 'veracious'},
#              'right': {'aright',
#               'compensate',
#               'correct',
#               'correctly',
#               'decent',
#               'decently',
#               'flop',
#               'good',
#               'in_good_order',
#               'justly',
#               'mightily',
#               'mighty',
#               'powerful',
#               'proper',
#               'properly',
#               'rectify',
#               'redress',
#               'right',
#               'right-hand',
#               'right_field',
#               'right_hand',
#               'right_on',
#               'right_wing',
#               'rightfield',
#               'rightfulness',
#               'ripe',
#               'the_right_way',
#               'veracious'},
#              'inaccurate': {'inaccurate'},
#              'away': {'aside', 'away', 'by', 'forth', 'off', 'out', 'outside'},
#              'outside': {'alfresco',
#               'away',
#               'exterior',
#               'external',
#               'extraneous',
#               'international',
#               'out-of-door',
#               'out_of_doors',
#               'outdoor',
#               'outdoors',
#               'outside',
#               'remote'},
#              'faulty': {'defective', 'faulty', 'incorrect', 'wrong'},
#              'incorrect': {'faulty', 'incorrect', 'wrong'},
#              'wrong': {'amiss',
#               'awry',
#               'damage',
#               'faulty',
#               'haywire',
#               'ill-timed',
#               'improper',
#               'incorrect',
#               'incorrectly',
#               'legal_injury',
#               'unseasonable',
#               'untimely',
#               'wrong',
#               'wrongfulness',
#               'wrongly'},
#              'unfaithful': {'faithless',
#               'traitorous',
#               'treasonable',
#               'treasonous',
#               'unfaithful'},
#              'wide_of_the_mark': {'wide', 'wide_of_the_mark'},
#              'wide': {'across-the-board',
#               'all-embracing',
#               'all-encompassing',
#               'all-inclusive',
#               'astray',
#               'blanket',
#               'broad',
#               'encompassing',
#               'extensive',
#               'full',
#               'panoptic',
#               'spacious',
#               'wide',
#               'wide-cut',
#               'wide-eyed',
#               'wide_of_the_mark',
#               'widely'},
#              'accustomed': {'accustomed', 'customary', 'habitual', 'wonted'},
#              'used_to': {'used_to', 'wont_to'},
#              'wont_to': {'used_to', 'wont_to'},
#              'unaccustomed': {'unaccustomed'},
#              'new': {'fresh',
#               'freshly',
#               'new',
#               'newfangled',
#               'newly',
#               'novel',
#               'raw',
#               'unexampled',
#               'young'},
#              'unused': {'fresh', 'idle', 'unused'},
#              'acidic': {'acid', 'acidic', 'acidulent', 'acidulous'},
#              'acid': {'Elvis',
#               'Lucy_in_the_sky_with_diamonds',
#               'Zen',
#               'acerb',
#               'acerbic',
#               'acid',
#               'acidic',
#               'acidulent',
#               'acidulous',
#               'acrid',
#               'back_breaker',
#               'battery-acid',
#               'bitter',
#               'blistering',
#               'caustic',
#               'dose',
#               'dot',
#               'loony_toons',
#               'pane',
#               'sulfurous',
#               'sulphurous',
#               'superman',
#               'virulent',
#               'vitriolic',
#               'window_pane'},
#              'acid-forming': {'acid-forming'},
#              'alkaline': {'alkalic', 'alkaline'},
#              'alkalic': {'alkalic', 'alkaline'},
#              'alcalescent': {'alcalescent', 'alkalescent'},
#              'alkalescent': {'alcalescent', 'alkalescent'},
#              'basic': {'basic',
#               'canonic',
#               'canonical',
#               'introductory',
#               'staple'},
#              'base-forming': {'base-forming'},
#              'saltlike': {'saltlike'},
#              'amphiprotic': {'amphiprotic', 'amphoteric'},
#              'amphoteric': {'amphiprotic', 'amphoteric'},
#              'acid-loving': {'acid-loving'},
#              'aciduric': {'acidophilic', 'acidophilous', 'aciduric'},
#              'acidophilic': {'acidophilic', 'acidophilous', 'aciduric'},
#              'acidophilous': {'acidophilic', 'acidophilous', 'aciduric'},
#              'alkaline-loving': {'alkaline-loving'},
#              'acknowledged': {'acknowledged'},
#              'recognized': {'accepted', 'recognised', 'recognized'},
#              'accepted': {'accepted', 'recognised', 'recognized'},
#              'recognised': {'accepted', 'recognised', 'recognized'},
#              'self-confessed': {'self-confessed'},
#              'assumptive': {'assuming', 'assumptive', 'presumptuous'},
#              'declarable': {'declarable'},
#              'given': {'apt',
#               'disposed',
#               'given',
#               'granted',
#               'minded',
#               'precondition',
#               'presumption',
#               'tending'},
#              'granted': {'given', 'granted'},
#              'putative': {'putative'},
#              'unacknowledged': {'unacknowledged'},
#              'unsung': {'obscure',
#               'unappreciated',
#               'unknown',
#               'unsung',
#               'unvalued'},
#              'unvalued': {'unappreciated', 'unsung', 'unvalued'},
#              'unappreciated': {'thankless',
#               'unappreciated',
#               'ungratifying',
#               'unsung',
#               'unvalued'},
#              'secret': {'arcanum',
#               'clandestine',
#               'cloak-and-dagger',
#               'closed_book',
#               'confidential',
#               'enigma',
#               'hidden',
#               'hole-and-corner',
#               'hugger-mugger',
#               'hush-hush',
#               'mysterious',
#               'mystery',
#               'mystic',
#               'mystical',
#               'occult',
#               'orphic',
#               'private',
#               'privy',
#               'secluded',
#               'secret',
#               'surreptitious',
#               'unavowed',
#               'undercover',
#               'underground'},
#              'unavowed': {'secret', 'sneaking', 'unavowed'},
#              'unconfessed': {'unconfessed'},
#              'unrecognised': {'unrecognised', 'unrecognized'},
#              'unrecognized': {'unrecognised', 'unrecognized'},
#              'acquisitive': {'acquisitive'},
#              'accumulative': {'accumulative', 'cumulative'},
#              'grabby': {'avaricious',
#               'covetous',
#               'grabby',
#               'grasping',
#               'greedy',
#               'prehensile'},
#              'covetous': {'avaricious',
#               'covetous',
#               'envious',
#               'grabby',
#               'grasping',
#               'greedy',
#               'jealous',
#               'prehensile'},
#              'grasping': {'avaricious',
#               'covetous',
#               'grabby',
#               'grasping',
#               'greedy',
#               'prehensile',
#               'prehension',
#               'seizing',
#               'taking_hold'},
#              'avaricious': {'avaricious',
#               'covetous',
#               'grabby',
#               'grasping',
#               'greedy',
#               'prehensile'},
#              'prehensile': {'avaricious',
#               'covetous',
#               'grabby',
#               'grasping',
#               'greedy',
#               'prehensile'},
#              'possessive': {'genitive',
#               'genitive_case',
#               'possessive',
#               'possessive_case'},
#              'plundering': {'pillage', 'pillaging', 'plundering'},
#              'predacious': {'predaceous', 'predacious', 'predatory'},
#              'predaceous': {'predaceous', 'predacious', 'predatory'},
#              'predatory': {'marauding',
#               'predaceous',
#               'predacious',
#               'predatory',
#               'raiding',
#               'rapacious',
#               'raptorial',
#               'ravening',
#               'vulturine',
#               'vulturous'},
#              'sordid': {'dirty',
#               'flyblown',
#               'seamy',
#               'seedy',
#               'sleazy',
#               'sordid',
#               'squalid'},
#              'unacquisitive': {'unacquisitive'},
#              'acropetal': {'acropetal'},
#              'basipetal': {'basipetal'},
#              'active': {'active',
#               'active_agent',
#               'active_voice',
#               'alive',
#               'combat-ready',
#               'dynamic',
#               'fighting',
#               'participating'},
#              'astir': {'about', 'astir', 'up'},
#              'about': {'about',
#               'almost',
#               'approximately',
#               'around',
#               'astir',
#               'close_to',
#               'just_about',
#               'more_or_less',
#               'most',
#               'near',
#               'nearly',
#               'nigh',
#               'or_so',
#               'roughly',
#               'some',
#               'virtually',
#               'well-nigh'},
#              'athletic': {'acrobatic', 'athletic', 'gymnastic'},
#              'gymnastic': {'acrobatic', 'athletic', 'gymnastic'},
#              'acrobatic': {'acrobatic', 'athletic', 'gymnastic'},
#              'spry': {'agile', 'nimble', 'quick', 'spry'},
#              'nimble': {'agile', 'nimble', 'quick', 'spry'},
#              'quick': {'agile',
#               'fast',
#               'flying',
#               'immediate',
#               'nimble',
#               'prompt',
#               'promptly',
#               'quick',
#               'quickly',
#               'ready',
#               'speedy',
#               'spry',
#               'straightaway',
#               'warm'},
#              'agile': {'agile', 'nimble', 'quick', 'spry'},
#              'hot': {'blistering',
#               'hot',
#               'live',
#               'raging',
#               'red-hot',
#               'spicy'},
#              'overactive': {'hyperactive', 'overactive'},
#              'hyperactive': {'hyperactive', 'overactive'},
#              'on_the_go': {'on_the_go'},
#              'sporty': {'clean',
#               'flashy',
#               'gaudy',
#               'jazzy',
#               'showy',
#               'sporting',
#               'sportsmanlike',
#               'sporty'},
#              'inactive': {'dormant',
#               'inactive',
#               'motionless',
#               'nonoperational',
#               'passive',
#               'static',
#               'still'},
#              'desk-bound': {'desk-bound', 'deskbound'},
#              'deskbound': {'desk-bound', 'deskbound'},
#              'dormant': {'abeyant',
#               'dormant',
#               'hibernating',
#               'inactive',
#               'sleeping',
#               'torpid'},
#              'abeyant': {'abeyant', 'dormant'},
#              'underactive': {'hypoactive', 'underactive'},
#              'hypoactive': {'hypoactive', 'underactive'},
#              'inert': {'indifferent',
#               'inert',
#               'neutral',
#               'sluggish',
#               'soggy',
#               'torpid'},
#              'sluggish': {'dull',
#               'inert',
#               'slow',
#               'sluggish',
#               'soggy',
#               'sulky',
#               'torpid'},
#              'soggy': {'boggy',
#               'doughy',
#               'inert',
#               'marshy',
#               'miry',
#               'mucky',
#               'muddy',
#               'quaggy',
#               'sloppy',
#               'sloughy',
#               'sluggish',
#               'soggy',
#               'squashy',
#               'swampy',
#               'torpid',
#               'waterlogged'},
#              'torpid': {'dormant',
#               'hibernating',
#               'inert',
#               'sluggish',
#               'soggy',
#               'torpid'},
#              'sedentary': {'sedentary'},
#              'activated': {'activated', 'excited'},
#              'off': {'away',
#               'bump_off',
#               'cancelled',
#               'dispatch',
#               'forth',
#               'hit',
#               'murder',
#               'off',
#               'polish_off',
#               'remove',
#               'slay',
#               'sour',
#               'turned'},
#              'retired': {'retired'},
#              'brisk': {'alert',
#               'bracing',
#               'brisk',
#               'brisk_up',
#               'brisken',
#               'fresh',
#               'lively',
#               'merry',
#               'rattling',
#               'refreshful',
#               'refreshing',
#               'snappy',
#               'spanking',
#               'tonic',
#               'zippy'},
#              'bustling': {'bustling'},
#              'busy': {'busy',
#               'busybodied',
#               'engaged',
#               'fussy',
#               'in_use',
#               'interfering',
#               'meddlesome',
#               'meddling',
#               'occupy',
#               'officious'},
#              'going': {'departure',
#               'exit',
#               'expiration',
#               'going',
#               'going_away',
#               'leaving',
#               'loss',
#               'passing',
#               'release',
#               'sledding'},
#              'open': {'afford',
#               'assailable',
#               'candid',
#               'capable',
#               'clear',
#               'exposed',
#               'give',
#               'heart-to-heart',
#               'loose',
#               'open',
#               'open_air',
#               'open_up',
#               'opened',
#               'out-of-doors',
#               'outdoors',
#               'overt',
#               'receptive',
#               'spread',
#               'spread_out',
#               'subject',
#               'surface',
#               'undecided',
#               'undefendable',
#               'undefended',
#               'undetermined',
#               'unfastened',
#               'unfold',
#               'unresolved'},
#              'springy': {'bouncy', 'live', 'lively', 'resilient', 'springy'},
#              'dark': {'benighted',
#               'black',
#               'blue',
#               'colored',
#               'coloured',
#               'dark',
#               'dark-skinned',
#               'darkness',
#               'dingy',
#               'disconsolate',
#               'dismal',
#               'dour',
#               'drab',
#               'drear',
#               'dreary',
#               'gloomy',
#               'glowering',
#               'glum',
#               'grim',
#               'iniquity',
#               'moody',
#               'morose',
#               'night',
#               'nighttime',
#               'non-white',
#               'obscure',
#               'saturnine',
#               'shadow',
#               'sinister',
#               'sorry',
#               'sour',
#               'sullen',
#               'wickedness'},
#              'dead': {'abruptly',
#               'absolutely',
#               'all_in',
#               'beat',
#               'bushed',
#               'dead',
#               'deadened',
#               'drained',
#               'idle',
#               'numb',
#               'perfectly',
#               'short',
#               'stagnant',
#               'suddenly',
#               'utter',
#               'utterly'},
#              'dull': {'benumb',
#               'blunt',
#               'boring',
#               'damp',
#               'dampen',
#               'deadening',
#               'dense',
#               'dim',
#               'dull',
#               'dumb',
#               'ho-hum',
#               'irksome',
#               'leaden',
#               'muffle',
#               'muffled',
#               'mute',
#               'muted',
#               'numb',
#               'obtuse',
#               'pall',
#               'slow',
#               'sluggish',
#               'softened',
#               'tedious',
#               'thudding',
#               'tiresome',
#               'tone_down',
#               'wearisome'},
#              'slow': {'behind',
#               'boring',
#               'deadening',
#               'decelerate',
#               'dense',
#               'dim',
#               'dull',
#               'dumb',
#               'easy',
#               'ho-hum',
#               'irksome',
#               'obtuse',
#               'retard',
#               'slack',
#               'slacken',
#               'slow',
#               'slow_down',
#               'slow_up',
#               'slowly',
#               'sluggish',
#               'tardily',
#               'tedious',
#               'tiresome',
#               'wearisome'},
#              'idle': {'baseless',
#               'dead',
#               'groundless',
#               'idle',
#               'jobless',
#               'laze',
#               'light',
#               'loose',
#               'out_of_work',
#               'slug',
#               'stagnate',
#               'tick_over',
#               'unfounded',
#               'unused',
#               'unwarranted',
#               'wild'},
#              'strikebound': {'strikebound'},
#              'progressive': {'continuous_tense',
#               'imperfect',
#               'imperfect_tense',
#               'liberal',
#               'liberalist',
#               'progressive',
#               'progressive_tense',
#               'reform-minded',
#               'reformist'},
#              'dead-end': {'dead-end'},
#              'flat': {'2-dimensional',
#               'apartment',
#               'bland',
#               'categoric',
#               'categorical',
#               'compressed',
#               'directly',
#               'flat',
#               'flat_tire',
#               'flatbed',
#               'flatcar',
#               'flavorless',
#               'flavourless',
#               'insipid',
#               'level',
#               'mat',
#               'matt',
#               'matte',
#               'matted',
#               'monotone',
#               'monotonic',
#               'monotonous',
#               'plane',
#               'prostrate',
#               'savorless',
#               'savourless',
#               'straight',
#               'two-dimensional',
#               'unconditional',
#               'vapid'},
#              'indolent': {'faineant',
#               'indolent',
#               'lazy',
#               'otiose',
#               'slothful',
#               'work-shy'},
#              'latent': {'latent'},
#              'quiescent': {'quiescent'},
#              'activist': {'activist', 'activistic', 'militant'},
#              'activistic': {'activist', 'activistic'},
#              'hands-on': {'hands-on'},
#              'proactive': {'proactive'},
#              'passive': {'inactive', 'passive', 'passive_voice', 'peaceful'},
#              'hands-off': {'hands-off'},
#              'supine': {'resistless', 'resupine', 'supine', 'unresisting'},
#              'resistless': {'irresistible',
#               'resistless',
#               'supine',
#               'unresisting'},
#              'unresisting': {'resistless', 'supine', 'unresisting'},
#              'eruptive': {'eruptive', 'igneous'},
#              'extinct': {'extinct', 'nonextant', 'out'},
#              'alive': {'active',
#               'alert',
#               'alive',
#               'animated',
#               'awake',
#               'live'},
#              'live': {'alive',
#               'be',
#               'bouncy',
#               'dwell',
#               'endure',
#               'exist',
#               'experience',
#               'go',
#               'hold_out',
#               'hold_up',
#               'hot',
#               'inhabit',
#               'know',
#               'last',
#               'live',
#               'live_on',
#               'lively',
#               'populate',
#               'resilient',
#               'springy',
#               'subsist',
#               'survive',
# ...
#               'wishful'},
#              'aspiring': {'aspirant', 'aspiring', 'wishful'},
#              'wishful': {'aspirant', 'aspiring', 'desirous', 'wishful'},
#              'driven': {'compulsive',
#               'determined',
#               'driven',
#               'goaded',
#               'impelled'},
#              'compulsive': {'compulsive', 'determined', 'driven'},
#              'determined': {'compulsive',
#               'determined',
#               'dictated',
#               'driven',
#               'set'},
#              'would-be': {'manque', 'would-be'},
#              'manque': {'manque', 'would-be'},
#              'overambitious': {'overambitious'},
#              'unambitious': {'ambitionless', 'unambitious'},
#              'ambitionless': {'ambitionless', 'unambitious'},
#              'shiftless': {'shiftless'},
#              'ametropic': {'ametropic'},
#              'emmetropic': {'emmetropic'},
#              'full': {'broad',
#               'entire',
#               'full',
#               'full-of-the-moon',
#               'full_moon',
#               'full_phase_of_the_moon',
#               'fully',
#               'good',
#               'replete',
#               'to_the_full',
#               'total',
#               'wax',
#               'wide',
#               'wide-cut'},
#              'generous': {'generous'},
#              'wide-cut': {'full', 'wide', 'wide-cut'},
#              'meagre': {'meager', 'meagerly', 'meagre', 'scrimpy', 'stingy'},
#              'scrimpy': {'meager', 'meagerly', 'meagre', 'scrimpy', 'stingy'},
#              'meager': {'meager', 'meagerly', 'meagre', 'scrimpy', 'stingy'},
#              'stingy': {'meager',
#               'meagerly',
#               'meagre',
#               'scrimpy',
#               'stingy',
#               'ungenerous'},
#              'meagerly': {'meager',
#               'meagerly',
#               'meagre',
#               'meagrely',
#               'scrimpy',
#               'slenderly',
#               'sparingly',
#               'stingy'},
#              'scanty': {'bare',
#               'pantie',
#               'panty',
#               'scanty',
#               'spare',
#               'step-in'},
#              'exiguous': {'exiguous'},
#              'hand-to-mouth': {'hand-to-mouth'},
#              'hardscrabble': {'hardscrabble'},
#              'miserable': {'abject',
#               'deplorable',
#               'execrable',
#               'hapless',
#               'low',
#               'low-down',
#               'measly',
#               'miserable',
#               'misfortunate',
#               'paltry',
#               'pathetic',
#               'piteous',
#               'pitiable',
#               'pitiful',
#               'poor',
#               'scummy',
#               'scurvy',
#               'suffering',
#               'woeful',
#               'wretched'},
#              'measly': {'measly', 'miserable', 'paltry'},
#              'paltry': {'measly',
#               'miserable',
#               'negligible',
#               'paltry',
#               'trifling'},
#              'anabolic': {'anabolic'},
#              'constructive-metabolic': {'constructive-metabolic',
#               'energy-storing'},
#              'energy-storing': {'constructive-metabolic', 'energy-storing'},
#              'catabolic': {'catabolic', 'katabolic'},
#              'katabolic': {'catabolic', 'katabolic'},
#              'energy-releasing': {'destructive-metabolic',
#               'energy-releasing',
#               'exoergic'},
#              'destructive-metabolic': {'destructive-metabolic',
#               'energy-releasing'},
#              'anaclinal': {'anaclinal'},
#              'cataclinal': {'cataclinal'},
#              'anastigmatic': {'anastigmatic', 'stigmatic'},
#              'stigmatic': {'anastigmatic', 'stigmatic', 'stigmatist'},
#              'astigmatic': {'astigmatic'},
#              'anticlinal': {'anticlinal'},
#              'synclinal': {'synclinal'},
#              'anadromous': {'anadromous'},
#              'catadromous': {'catadromous'},
#              'diadromous': {'diadromous'},
#              'anabatic': {'anabatic'},
#              'katabatic': {'catabatic', 'katabatic'},
#              'catabatic': {'catabatic', 'katabatic'},
#              'anal': {'anal', 'anal_retentive'},
#              'anal_retentive': {'anal', 'anal_retentive'},
#              'oral': {'oral',
#               'oral_exam',
#               'oral_examination',
#               'unwritten',
#               'viva',
#               'viva_voce'},
#              'analogue': {'analog', 'analogue', 'linear', 'parallel'},
#              'linear': {'additive',
#               'analog',
#               'analogue',
#               'elongate',
#               'linear',
#               'one-dimensional',
#               'running'},
#              'analog': {'analog', 'analogue', 'linear', 'parallel'},
#              'digital': {'digital'},
#              'analytical': {'analytic', 'analytical'},
#              'analytic': {'analytic', 'analytical', 'uninflected'},
#              'synthetic': {'celluloid',
#               'man-made',
#               'semisynthetic',
#               'synthetic',
#               'synthetic_substance',
#               'synthetical'},
#              'synthetical': {'synthetic', 'synthetical'},
#              'uninflected': {'analytic', 'uninflected'},
#              'isolating': {'isolating'},
#              'polysynthetic': {'agglutinative', 'polysynthetic'},
#              'inflectional': {'inflectional'},
#              'derivational': {'derivational'},
#              'apocarpous': {'apocarpous'},
#              'syncarpous': {'syncarpous'},
#              'angry': {'angry', 'furious', 'raging', 'tempestuous', 'wild'},
#              'provoked': {'aggravated', 'provoked'},
#              'aggravated': {'aggravated', 'provoked'},
#              'furious': {'angered',
#               'angry',
#               'enraged',
#               'ferocious',
#               'fierce',
#               'furious',
#               'infuriated',
#               'maddened',
#               'raging',
#               'savage',
#               'tempestuous',
#               'wild'},
#              'enraged': {'angered',
#               'enraged',
#               'furious',
#               'infuriated',
#               'maddened'},
#              'infuriated': {'angered',
#               'enraged',
#               'furious',
#               'infuriated',
#               'maddened'},
#              'maddened': {'angered',
#               'enraged',
#               'furious',
#               'infuriated',
#               'maddened'},
#              'angered': {'angered',
#               'enraged',
#               'furious',
#               'infuriated',
#               'maddened'},
#              'black': {'black',
#               'black-market',
#               'blacken',
#               'blackened',
#               'blackness',
#               'bleak',
#               'bootleg',
#               'calamitous',
#               'contraband',
#               'dark',
#               'dim',
#               'disastrous',
#               'disgraceful',
#               'fatal',
#               'fateful',
#               'grim',
#               'ignominious',
#               'inglorious',
#               'inkiness',
#               'lightlessness',
#               'melanise',
#               'melanize',
#               'mordant',
#               'nigrify',
#               'opprobrious',
#               'pitch-black',
#               'pitch-dark',
#               'pitch_blackness',
#               'shameful',
#               'sinister',
#               'smuggled',
#               'smutty',
#               'total_darkness'},
#              'irascible': {'choleric',
#               'hot-tempered',
#               'hotheaded',
#               'irascible',
#               'quick-tempered',
#               'short-tempered'},
#              'choleric': {'choleric',
#               'hot-tempered',
#               'hotheaded',
#               'irascible',
#               'quick-tempered',
#               'short-tempered'},
#              'hot_under_the_collar': {'hot_under_the_collar'},
#              'mad': {'brainsick',
#               'crazy',
#               'delirious',
#               'demented',
#               'disturbed',
#               'excited',
#               'frantic',
#               'harebrained',
#               'huffy',
#               'insane',
#               'mad',
#               'sick',
#               'sore',
#               'unbalanced',
#               'unhinged',
#               'unrestrained'},
#              'huffy': {'feisty',
#               'huffy',
#               'mad',
#               'sore',
#               'thin-skinned',
#               'touchy'},
#              'sore': {'afflictive',
#               'huffy',
#               'mad',
#               'painful',
#               'raw',
#               'sensitive',
#               'sore',
#               'tender'},
#              'outraged': {'incensed', 'indignant', 'outraged', 'umbrageous'},
#              'incensed': {'incensed', 'indignant', 'outraged', 'umbrageous'},
#              'indignant': {'incensed', 'indignant', 'outraged', 'umbrageous'},
#              'umbrageous': {'incensed',
#               'indignant',
#               'outraged',
#               'shadowed',
#               'shadowy',
#               'shady',
#               'umbrageous'},
#              'ireful': {'irate', 'ireful'},
#              'irate': {'irate', 'ireful'},
#              'livid': {'ashen',
#               'black-and-blue',
#               'blanched',
#               'bloodless',
#               'livid',
#               'white'},
#              'smoldering': {'smoldering', 'smouldering'},
#              'smouldering': {'smoldering', 'smouldering'},
#              'wrathful': {'wrathful', 'wroth', 'wrothful'},
#              'wrothful': {'wrathful', 'wroth', 'wrothful'},
#              'wroth': {'wrathful', 'wroth', 'wrothful'},
#              'unangry': {'unangry'},
#              'resentful': {'resentful'},
#              'bitter': {'acerb',
#               'acerbic',
#               'acid',
#               'acrid',
#               'acrimonious',
#               'biting',
#               'bitingly',
#               'bitter',
#               'bitterly',
#               'bitterness',
#               'blistering',
#               'caustic',
#               'piercingly',
#               'sulfurous',
#               'sulphurous',
#               'virulent',
#               'vitriolic'},
#              'acrimonious': {'acrimonious', 'bitter'},
#              'rancorous': {'rancorous'},
#              'unresentful': {'unresentful'},
#              'unbitter': {'unbitter'},
#              'sentient': {'animate', 'sentient'},
#              'animate': {'animate',
#               'animise',
#               'animize',
#               'enliven',
#               'exalt',
#               'inspire',
#               'invigorate',
#               'liven',
#               'liven_up',
#               'quicken',
#               'reanimate',
#               'recreate',
#               'renovate',
#               'repair',
#               'revive',
#               'revivify',
#               'sentient',
#               'vivify'},
#              'sensate': {'sensate'},
#              'insentient': {'insensate', 'insentient'},
#              'insensate': {'cold',
#               'cold-blooded',
#               'inhuman',
#               'insensate',
#               'insentient'},
#              'unfeeling': {'hardhearted', 'stonyhearted', 'unfeeling'},
#              'nonliving': {'inanimate', 'non-living', 'nonliving'},
#              'non-living': {'inanimate', 'non-living', 'nonliving'},
#              'nonconscious': {'nonconscious'},
#              'animated': {'alive', 'animated'},
#              'enlivened': {'enlivened', 'spirited'},
#              'spirited': {'bouncing',
#               'bouncy',
#               'enlivened',
#               'game',
#               'gamey',
#               'gamy',
#               'gritty',
#               'mettlesome',
#               'peppy',
#               'spirited',
#               'spunky',
#               'zippy'},
#              'full_of_life': {'full_of_life', 'lively', 'vital'},
#              'lively': {'alert',
#               'bouncy',
#               'brisk',
#               'full_of_life',
#               'live',
#               'lively',
#               'merry',
#               'racy',
#               'rattling',
#               'resilient',
#               'snappy',
#               'spanking',
#               'springy',
#               'vital',
#               'zippy'},
#              'reanimated': {'reanimated', 'revived'},
#              'revived': {'reanimated', 'revived'},
#              'unanimated': {'unanimated'},
#              'wan': {'pale', 'pallid', 'sick', 'wan'},
#              'perked_up': {'perked_up'},
#              'unenlivened': {'unenlivened'},
#              'anonymous': {'anon.', 'anonymous'},
#              'anon.': {'anon.', 'anonymous'},
#              'unknown': {'alien',
#               'nameless',
#               'obscure',
#               'strange',
#               'stranger',
#               'terra_incognita',
#               'unidentified',
#               'unknown',
#               'unknown_quantity',
#               'unknown_region',
#               'unnamed',
#               'unsung'},
#              'nameless': {'nameless', 'unidentified', 'unknown', 'unnamed'},
#              'unidentified': {'nameless',
#               'unidentified',
#               'unknown',
#               'unnamed'},
#              'unnamed': {'nameless', 'unidentified', 'unknown', 'unnamed'},
#              'onymous': {'onymous'},
#              'binominal': {'binomial', 'binominal'},
#              'binomial': {'binomial', 'binominal'},
#              'pseudonymous': {'pseudonymous'},
#              'antemortem': {'antemortem'},
#              'postmortal': {'postmortal', 'postmortem'},
#              'postmortem': {'PM',
#               'autopsy',
#               'necropsy',
#               'post-mortem',
#               'post-mortem_examination',
#               'postmortal',
#               'postmortem',
#               'postmortem_examination'},
#              'antecedent': {'ancestor',
#               'antecedent',
#               'ascendant',
#               'ascendent',
#               'forerunner',
#               'root'},
#              'anterior': {'anterior', 'front_tooth', 'prior'},
#              'prior': {'anterior', 'prior'},
#              'anticipatory': {'anticipatory', 'prevenient'},
#              'prevenient': {'anticipatory', 'prevenient'},
#              'preexisting': {'pre-existent',
#               'pre-existing',
#               'preexistent',
#               'preexisting'},
#              'preexistent': {'pre-existent',
#               'pre-existing',
#               'preexistent',
#               'preexisting'},
#              'pre-existent': {'pre-existent',
#               'pre-existing',
#               'preexistent',
#               'preexisting'},
#              'pre-existing': {'pre-existent',
#               'pre-existing',
#               'preexistent',
#               'preexisting'},
#              'subsequent': {'subsequent'},
#              'accompanying': {'accompanying',
#               'attendant',
#               'concomitant',
#               'consequent',
#               'ensuant',
#               'incidental',
#               'resultant',
#               'sequent'},
#              'resultant': {'accompanying',
#               'attendant',
#               'concomitant',
#               'consequent',
#               'end_point',
#               'ensuant',
#               'final_result',
#               'incidental',
#               'outcome',
#               'result',
#               'resultant',
#               'sequent',
#               'termination',
#               'vector_sum'},
#              'consequent': {'accompanying',
#               'attendant',
#               'concomitant',
#               'consequent',
#               'ensuant',
#               'incidental',
#               'resultant',
#               'sequent'},
#              'incidental': {'accompanying',
#               'attendant',
#               'concomitant',
#               'consequent',
#               'ensuant',
#               'incident',
#               'incidental',
#               'incidental_expense',
#               'minor_expense',
#               'nonessential',
#               'resultant',
#               'sequent'},
#              ...})

# %% [markdown]
# ### Reproducing the WordNet synonym graph experiment

# %% [markdown]
# For our VSM, let's use the 300d file included in this distribution from the GloVe team, as it is close to or identical to the one used in the paper:
#
# http://nlp.stanford.edu/data/glove.6B.zip
#
# If you download this archive, place it in `vsmdata`, and unpack it, then the following will load the file into a dictionary for you:

# %%
glove_dict = utils.glove2dict(
    os.path.join(data_home, 'glove.6B', 'glove.6B.300d.txt'))

# %% [markdown]
# This is the initial embedding space $\widehat{Q}$:

# %%
X_glove = pd.DataFrame(glove_dict).T

# %%
X_glove.T.shape

# %% [markdown]
# Now we just need to replace all of the strings in `edges` with indices into `X_glove`:

# %%
def convert_edges_to_indices(edges, Q):
    lookup = dict(zip(Q.index, range(Q.shape[0])))
    index_edges = defaultdict(set)
    for start, finish_nodes in edges.items():
        s = lookup.get(start)
        if s:
            f = {lookup[n] for n in finish_nodes if n in lookup}
            if f:
                index_edges[s] = f
    return index_edges

# %%
wn_index_edges = convert_edges_to_indices(wn_edges, X_glove)

# %% [markdown]
# And now we can retrofit:

# %%
wn_retro = Retrofitter(verbose=True)

# %%
X_retro = wn_retro.fit(X_glove, wn_index_edges)

# %% [markdown]
# You can now evaluate `X_retro` using the homework/bake-off notebook [hw_wordsim.ipynb](hw_wordsim.ipynb)!

# %%
# Optionally write `X_retro` to disk for use elsewhere:
#
# X_retro.to_csv(
#     os.path.join(data_home, 'glove6B300d-retrofit-wn.csv.gz'), compression='gzip')

# %% [markdown]
# ## Other retrofitting models and ideas
#
# * The retrofitting idea is very close to __graph embedding__, in which one learns distributed representations of nodes based on their position in the graph. See [Hamilton et al. 2017](https://arxiv.org/pdf/1709.05584.pdf) for an overview of these methods. There are numerous parallels with the material we've reviewed here.
#
# * If you think of the input VSM as a "warm start" for graph embedding algorithms, then you're essentially retrofitting. This connection opens up a number of new opportunities to go beyond the similarity-based semantics that underlies Faruqui et al.'s model. See [Lengerich et al. 2017](https://arxiv.org/pdf/1708.00112.pdf), section 3.2, for more on these connections.
#
# * [Mrkšić  et al. 2016](https://aclanthology.coli.uni-saarland.de/papers/N16-1018/n16-1018) address the limitation of Faruqui et al's model that it assumes connected nodes in the graph are similar. In a graph with complex, varied edge semantics, this is likely to be false. They address the case of antonymy in particular.
#
# * [Lengerich et al. 2017](https://arxiv.org/pdf/1708.00112.pdf) present a __functional retrofitting__ framework in which the edge meanings are explicitly modeled, and they evaluate instantiations of the framework with linear and neural edge penalty functions. (The Faruqui et al. model emerges as a specific instantiation of this framework.)
